# %% [markdown]
# https://itnext.io/visualize-your-rag-data-eda-for-retrieval-augmented-generation-0701ee98768f

# %% [markdown]
#     Prepare Documents: Start by collecting data. This tutorial uses Formula One data from Wikipedia in HTML format as an example to build a dataset for our RAG application. You can also use your own data here!
#     Split and Create Embeddings: Break down the collected documents into smaller snippets and use an embedding model to convert them into compact vector representations. This involves utilizing a splitter, OpenAI’s text-embedding-ada-002, and ChromaDB as vector store.
#     Build a LangChain: Set up the LangChain by combining a prompt generator for context creation, a retriever for fetching relevant snippets, and an LLM (GPT-4) to answer queries.
#     Ask a Question: Learn how to ask questions to the RAG application.
#     Visualize: Use Renumics-Spotlight visualize the embeddings in 2D, and analyze the relationships and proximities between queries and document snippets.

# %%
# !pip install langchain langchain-openai chromadb renumics-spotlight
# Out:
# Collecting langchain
#   Downloading langchain-0.1.7-py3-none-any.whl.metadata (13 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-0.0.6-py3-none-any.whl.metadata (2.5 kB)
# Collecting chromadb
#   Downloading chromadb-0.4.22-py3-none-any.whl.metadata (7.3 kB)
# Collecting renumics-spotlight
#   Downloading renumics_spotlight-1.6.4-py3-none-any.whl.metadata (5.4 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.27-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.20 (from langchain)
#   Downloading langchain_community-0.0.20-py3-none-any.whl.metadata (8.1 kB)
# Collecting langchain-core<0.2,>=0.1.22 (from langchain)
#   Downloading langchain_core-0.1.23-py3-none-any.whl.metadata (6.0 kB)
# Collecting langsmith<0.1,>=0.0.83 (from langchain)
#   Downloading langsmith-0.0.90-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from langchain) (1.26.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from langchain) (2.6.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from langchain) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting openai<2.0.0,>=1.10.0 (from langchain-openai)
#   Downloading openai-1.12.0-py3-none-any.whl.metadata (18 kB)
# Collecting tiktoken<1,>=0.5.2 (from langchain-openai)
#   Downloading tiktoken-0.6.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp311-cp311-win_amd64.whl.metadata (262 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.109.2-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.27.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.4.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from chromadb) (4.9.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.4.0-cp311-cp311-win_amd64.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.17.0-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.22.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.15.2-cp311-none-win_amd64.whl.metadata (6.8 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 0.0/67.3 kB ? eta -:--:--
#      ------------------------------------ --- 61.4/67.3 kB ? eta -:--:--
#      ------------------------------------ --- 61.4/67.3 kB ? eta -:--:--
#      ------------------------------------ --- 61.4/67.3 kB ? eta -:--:--
#      -------------------------------------- 67.3/67.3 kB 331.5 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from chromadb) (4.66.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.60.1-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting aiofiles (from renumics-spotlight)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting appdirs (from renumics-spotlight)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting av (from renumics-spotlight)
#   Downloading av-11.0.0-cp311-cp311-win_amd64.whl.metadata (4.7 kB)
# Collecting cleanlab (from renumics-spotlight)
#   Downloading cleanlab-2.5.0-py3-none-any.whl.metadata (23 kB)
# Collecting cleanvision (from renumics-spotlight)
#   Downloading cleanvision-0.3.6-py3-none-any.whl.metadata (51 kB)
#      ---------------------------------------- 0.0/51.5 kB ? eta -:--:--
#      ---------------------------------------  51.2/51.5 kB ? eta -:--:--
#      ---------------------------------------  51.2/51.5 kB ? eta -:--:--
#      ---------------------------------------  51.2/51.5 kB ? eta -:--:--
#      -------------------------------------- 51.5/51.5 kB 264.4 kB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from renumics-spotlight) (8.1.7)
# Collecting databases[aiosqlite] (from renumics-spotlight)
#   Downloading databases-0.8.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting datasets<3.0.0,>=2.12.0 (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading datasets-2.17.0-py3-none-any.whl.metadata (20 kB)
# Collecting diskcache (from renumics-spotlight)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting filetype (from renumics-spotlight)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting h5py>3.0 (from renumics-spotlight)
#   Downloading h5py-3.10.0-cp311-cp311-win_amd64.whl.metadata (2.5 kB)
# Collecting httptools (from renumics-spotlight)
#   Downloading httptools-0.6.1-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting httpx<0.24.0,>=0.23.0 (from renumics-spotlight)
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#      ---------------------------------- ----- 61.4/71.5 kB ? eta -:--:--
#      ---------------------------------- ----- 61.4/71.5 kB ? eta -:--:--
#      ---------------------------------- ----- 61.4/71.5 kB ? eta -:--:--
#      ---------------------------------- ----- 61.4/71.5 kB ? eta -:--:--
#      ---------------------------------- ----- 61.4/71.5 kB ? eta -:--:--
#      -------------------------------------- 71.5/71.5 kB 244.9 kB/s eta 0:00:00
# Collecting imagecodecs (from renumics-spotlight)
#   Downloading imagecodecs-2024.1.1-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting imageio>=2.18.0 (from renumics-spotlight)
#   Downloading imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-5.7.1-py3-none-any.whl (28 kB)
# Collecting ipywidgets (from renumics-spotlight)
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from renumics-spotlight) (3.1.3)
# Collecting loguru (from renumics-spotlight)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Collecting networkx (from renumics-spotlight)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting numba<0.58.0,>=0.57.1 (from renumics-spotlight)
#   Downloading numba-0.57.1-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Collecting orjson (from renumics-spotlight)
#   Downloading orjson-3.9.13-cp311-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.6 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/50.6 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/50.6 kB ? eta -:--:--
#      -------------------------------------- 50.6/50.6 kB 366.9 kB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from renumics-spotlight) (23.2)
# Collecting pandas (from renumics-spotlight)
#   Downloading pandas-2.2.0-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting pillow<11.0.0,>=10.0.0 (from renumics-spotlight)
#   Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting prettytable (from renumics-spotlight)
#   Downloading prettytable-3.9.0-py3-none-any.whl.metadata (26 kB)
# Collecting py-machineid (from renumics-spotlight)
#   Downloading py_machineid-0.5.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyarrow<15.0.0,>=14.0.2 (from renumics-spotlight)
#   Downloading pyarrow-14.0.2-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting pydantic-settings<3.0.0,>=2.0.3 (from renumics-spotlight)
#   Downloading pydantic_settings-2.1.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pygltflib>=1.15.1 (from renumics-spotlight)
#   Downloading pygltflib-1.16.1.tar.gz (42 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      -------------------------------------- - 41.0/42.0 kB ? eta -:--:--
#      -------------------------------------- - 41.0/42.0 kB ? eta -:--:--
#      -------------------------------------- - 41.0/42.0 kB ? eta -:--:--
#      -------------------------------------- 42.0/42.0 kB 202.6 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting rsa (from renumics-spotlight)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting scikit-image (from renumics-spotlight)
#   Downloading scikit_image-0.22.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting scikit-learn (from renumics-spotlight)
#   Downloading scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from renumics-spotlight) (65.5.0)
# Collecting toml (from renumics-spotlight)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting transformers<5.0.0,>=4.35.2 (from renumics-spotlight)
#   Downloading transformers-4.37.2-py3-none-any.whl.metadata (129 kB)
#      ---------------------------------------- 0.0/129.4 kB ? eta -:--:--
#      ------------------------------------ - 122.9/129.4 kB 7.0 MB/s eta 0:00:01
#      ------------------------------------ - 122.9/129.4 kB 7.0 MB/s eta 0:00:01
#      -------------------------------------- 129.4/129.4 kB 1.1 MB/s eta 0:00:00
# Collecting trimesh (from renumics-spotlight)
#   Downloading trimesh-4.1.3-py3-none-any.whl.metadata (18 kB)
# Collecting umap-learn (from renumics-spotlight)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ---------------------------------------- 0.0/90.9 kB ? eta -:--:--
#      ------------------------------------ --- 81.9/90.9 kB 4.8 MB/s eta 0:00:01
#      ---------------------------------------- 90.9/90.9 kB 1.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting validators (from renumics-spotlight)
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting websockets (from renumics-spotlight)
#   Downloading websockets-12.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: colorama in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.20.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting filelock (from datasets<3.0.0,>=2.12.0->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyarrow-hotfix (from datasets<3.0.0,>=2.12.0->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<3.0.0,>=2.12.0->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets<3.0.0,>=2.12.0->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets<3.0.0,>=2.12.0->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2023.10.0,>=2023.1.0 (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets<3.0.0,>=2.12.0->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting huggingface-hub>=0.19.4 (from datasets<3.0.0,>=2.12.0->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting soundfile>=0.12.1 (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      -------------------- ------------------- 0.5/1.0 MB 15.7 MB/s eta 0:00:01
#      ---------------------------------------  1.0/1.0 MB 15.8 MB/s eta 0:00:01
#      ---------------------------------------  1.0/1.0 MB 15.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 7.1 MB/s eta 0:00:00
# Collecting librosa (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading librosa-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: certifi in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from httpx<0.24.0,>=0.23.0->renumics-spotlight) (2024.2.2)
# Collecting httpcore<0.17.0,>=0.15.0 (from httpx<0.24.0,>=0.23.0->renumics-spotlight)
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ---------------------------------------- 0.0/69.6 kB ? eta -:--:--
#      ----------------------------------- ---- 61.4/69.6 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 69.6/69.6 kB 760.5 kB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from rfc3986[idna2008]<2,>=1.3->httpx<0.24.0,>=0.23.0->renumics-spotlight)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio (from httpx<0.24.0,>=0.23.0->renumics-spotlight)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Downloading google_auth-2.27.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Downloading websocket_client-1.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#      ------------------------------------- -- 143.4/151.7 kB ? eta -:--:--
#      ------------------------------------- -- 143.4/151.7 kB ? eta -:--:--
#      -------------------------------------- 151.7/151.7 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.0)
# Collecting anyio<5,>=3 (from langchain-core<0.2,>=0.1.22->langchain)
#   Downloading anyio-4.2.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting langsmith<0.1,>=0.0.83 (from langchain)
#   Downloading langsmith-0.0.87-py3-none-any.whl.metadata (10 kB)
# Collecting llvmlite<0.41,>=0.40.0dev0 (from numba<0.58.0,>=0.57.1->renumics-spotlight)
#   Downloading llvmlite-0.40.1-cp311-cp311-win_amd64.whl.metadata (4.8 kB)
# Collecting numpy<2,>=1 (from langchain)
#   Downloading numpy-1.24.4-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/46.0 kB ? eta -:--:--
#      -------------------------------------- 46.0/46.0 kB 577.1 kB/s eta 0:00:00
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-4.25.2-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#      ---- ----------------------------------- 0.6/5.7 MB 12.9 MB/s eta 0:00:01
#      --------- ------------------------------ 1.4/5.7 MB 15.0 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.6/5.7 MB 14.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.6/5.7 MB 14.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.7/5.7 MB 7.1 MB/s eta 0:00:01
#      --------------- ------------------------ 2.2/5.7 MB 7.7 MB/s eta 0:00:01
#      ------------------- -------------------- 2.8/5.7 MB 8.8 MB/s eta 0:00:01
#      ------------------------- -------------- 3.6/5.7 MB 10.0 MB/s eta 0:00:01
#      -------------------------- ------------- 3.9/5.7 MB 9.8 MB/s eta 0:00:01
#      -------------------------- ------------- 3.9/5.7 MB 9.8 MB/s eta 0:00:01
#      -------------------------- ------------- 3.9/5.7 MB 9.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 4.3/5.7 MB 8.0 MB/s eta 0:00:01
#      ------------------------------ --------- 4.3/5.7 MB 7.6 MB/s eta 0:00:01
#      ------------------------------- -------- 4.6/5.7 MB 7.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 4.9/5.7 MB 7.3 MB/s eta 0:00:01
#      ---------------------------------------  5.6/5.7 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------- 5.7/5.7 MB 5.9 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.10.0->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.22.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl.metadata (5.9 kB)
# Collecting opentelemetry-semantic-conventions==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading wrapt-1.16.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.7.2-py3-none-any.whl.metadata (9.2 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.1 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from pydantic<3,>=1->langchain) (2.16.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.0.3->renumics-spotlight)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.6)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.0.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.5.2->langchain-openai)
#   Downloading regex-2023.12.25-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------  41.0/42.0 kB ? eta -:--:--
#      ---------------------------------------  41.0/42.0 kB ? eta -:--:--
#      ---------------------------------------  41.0/42.0 kB ? eta -:--:--
#      ---------------------------------------  41.0/42.0 kB ? eta -:--:--
#      -------------------------------------- 42.0/42.0 kB 168.8 kB/s eta 0:00:00
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.35.2->renumics-spotlight)
#   Downloading safetensors-0.4.2-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Collecting h11>=0.8 (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/58.3 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/58.3 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/58.3 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/58.3 kB ? eta -:--:--
#      -------------------------------------- 58.3/58.3 kB 255.4 kB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp311-none-win_amd64.whl.metadata (5.0 kB)
# Collecting termcolor>=2.0.0 (from cleanlab->renumics-spotlight)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting pytz>=2020.1 (from pandas->renumics-spotlight)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->renumics-spotlight)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn->renumics-spotlight)
#   Downloading scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.4 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.4 kB ? eta -:--:--
#      -------------------------------------- 60.4/60.4 kB 460.6 kB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn->renumics-spotlight)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->renumics-spotlight)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting tabulate>=0.8.3 (from cleanvision->renumics-spotlight)
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting imagehash>=4.2.0 (from cleanvision->renumics-spotlight)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ---------------------------------------- 0.0/296.5 kB ? eta -:--:--
#      -------------------------------------- - 286.7/296.5 kB ? eta -:--:--
#      -------------------------------------- - 286.7/296.5 kB ? eta -:--:--
#      -------------------------------------- 296.5/296.5 kB 3.7 MB/s eta 0:00:00
# Collecting matplotlib>=3.4 (from cleanvision->renumics-spotlight)
#   Downloading matplotlib-3.8.2-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-1.4.51-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Collecting aiosqlite (from databases[aiosqlite]->renumics-spotlight)
#   Downloading aiosqlite-0.19.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipywidgets->renumics-spotlight) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipywidgets->renumics-spotlight) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipywidgets->renumics-spotlight) (5.14.1)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets->renumics-spotlight)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets->renumics-spotlight)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from jinja2->renumics-spotlight) (2.1.5)
# Collecting win32-setctime>=1.0.0 (from loguru->renumics-spotlight)
#   Downloading win32_setctime-1.1.0-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: wcwidth in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from prettytable->renumics-spotlight) (0.2.13)
# Collecting winregistry (from py-machineid->renumics-spotlight)
#   Downloading winregistry-1.1.1-py3-none-any.whl (5.8 kB)
# Collecting pyasn1>=0.1.3 (from rsa->renumics-spotlight)
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->renumics-spotlight)
#   Downloading tifffile-2024.2.12-py3-none-any.whl.metadata (31 kB)
# Collecting lazy_loader>=0.3 (from scikit-image->renumics-spotlight)
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting pynndescent>=0.5 (from umap-learn->renumics-spotlight)
#   Downloading pynndescent-0.5.11-py3-none-any.whl.metadata (6.8 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ---------------------------------------- 0.0/181.3 kB ? eta -:--:--
#      ------------------------------------ - 174.1/181.3 kB 5.3 MB/s eta 0:00:01
#      ------------------------------------ - 174.1/181.3 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------- 181.3/181.3 kB 1.4 MB/s eta 0:00:00
# Collecting PyWavelets (from imagehash>=4.2.0->cleanvision->renumics-spotlight)
#   Downloading pywavelets-1.5.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting zipp>=0.5 (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: decorator in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->renumics-spotlight) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->renumics-spotlight) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->renumics-spotlight) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->renumics-spotlight) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->renumics-spotlight) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->renumics-spotlight) (0.6.3)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.4->cleanvision->renumics-spotlight)
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.4->cleanvision->renumics-spotlight)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.4->cleanvision->renumics-spotlight)
#   Downloading fonttools-4.48.1-cp311-cp311-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.2 kB ? eta -:--:--
#      ----------------------------------- -- 153.6/162.2 kB 9.6 MB/s eta 0:00:01
#      -------------------------------------- 162.2/162.2 kB 1.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.4->cleanvision->renumics-spotlight)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.4->cleanvision->renumics-spotlight)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting cffi>=1.0 (from soundfile>=0.12.1->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata (1.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ------------------------------------- -- 81.9/86.8 kB ? eta -:--:--
#      -------------------------------------- 86.8/86.8 kB 981.5 kB/s eta 0:00:00
# Collecting audioread>=2.1.9 (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting pooch>=1.0 (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading pooch-1.8.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting soxr>=0.3.2 (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading soxr-0.3.7-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# Collecting msgpack>=1.0 (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading msgpack-1.0.7-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Collecting mpmath>=0.19 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ------------------------------------  522.2/536.2 kB 16.5 MB/s eta 0:00:01
#      ------------------------------------  532.5/536.2 kB 11.1 MB/s eta 0:00:01
#      -------------------------------------- 536.2/536.2 kB 4.2 MB/s eta 0:00:00
# Collecting pycparser (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#      ------------------------------------- -- 112.6/118.7 kB ? eta -:--:--
#      -------------------------------------- 118.7/118.7 kB 1.2 MB/s eta 0:00:00
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      -------------------------------------- - 92.2/95.2 kB ? eta -:--:--
#      -------------------------------------- - 92.2/95.2 kB ? eta -:--:--
#      -------------------------------------- 95.2/95.2 kB 779.5 kB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->renumics-spotlight) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from pooch>=1.0->librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (4.2.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->renumics-spotlight) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->renumics-spotlight) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ghadf\vscode_projects\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->renumics-spotlight) (0.2.2)
# Downloading langchain-0.1.7-py3-none-any.whl (815 kB)
#    ---------------------------------------- 0.0/815.9 kB ? eta -:--:--
#    ----------------------------- --------- 624.6/815.9 kB 19.8 MB/s eta 0:00:01
#    --------------------------------------  809.0/815.9 kB 17.0 MB/s eta 0:00:01
#    --------------------------------------  809.0/815.9 kB 17.0 MB/s eta 0:00:01
#    --------------------------------------  809.0/815.9 kB 17.0 MB/s eta 0:00:01
#    ---------------------------------------- 815.9/815.9 kB 4.3 MB/s eta 0:00:00
# Downloading langchain_openai-0.0.6-py3-none-any.whl (29 kB)
# Downloading chromadb-0.4.22-py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.0 kB ? eta -:--:--
#    --------------------------------------  501.8/509.0 kB 30.7 MB/s eta 0:00:01
#    --------------------------------------  501.8/509.0 kB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 509.0/509.0 kB 5.3 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.3-cp311-cp311-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.6 kB ? eta -:--:--
#    ------------------------------------- -- 143.4/151.6 kB ? eta -:--:--
#    ---------------------------------------- 151.6/151.6 kB 1.8 MB/s eta 0:00:00
# Downloading renumics_spotlight-1.6.4-py3-none-any.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.7/3.1 MB 22.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.4/3.1 MB 17.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.3/3.1 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.7/3.1 MB 18.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.7/3.1 MB 13.2 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.1 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.1 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 7.5 MB/s eta 0:00:00
# Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl (365 kB)
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------  358.4/365.3 kB ? eta -:--:--
#    ---------------------------------------  358.4/365.3 kB ? eta -:--:--
#    ---------------------------------------- 365.3/365.3 kB 3.8 MB/s eta 0:00:00
# Downloading bcrypt-4.1.2-cp39-abi3-win_amd64.whl (158 kB)
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    -------------------------------------- - 153.6/158.3 kB ? eta -:--:--
#    ---------------------------------------- 158.3/158.3 kB 2.4 MB/s eta 0:00:00
# Downloading build-1.0.3-py3-none-any.whl (18 kB)
# Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Downloading datasets-2.17.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.6 kB ? eta -:--:--
#    --------------------------------------  532.5/536.6 kB 16.8 MB/s eta 0:00:01
#    --------------------------------------  532.5/536.6 kB 16.8 MB/s eta 0:00:01
#    --------------------------------------  532.5/536.6 kB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 536.6/536.6 kB 4.2 MB/s eta 0:00:00
# Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
#    ---------------------------------------- 0.0/92.1 kB ? eta -:--:--
#    ----------------------------------- ---- 81.9/92.1 kB ? eta -:--:--
#    ----------------------------------- ---- 81.9/92.1 kB ? eta -:--:--
#    ---------------------------------------- 92.1/92.1 kB 1.0 MB/s eta 0:00:00
# Downloading grpcio-1.60.1-cp311-cp311-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.7 MB 25.1 MB/s eta 0:00:01
#    ------------------ --------------------- 1.7/3.7 MB 18.3 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.7 MB 20.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.4/3.7 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 9.5 MB/s eta 0:00:00
# Downloading h5py-3.10.0-cp311-cp311-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.9/2.7 MB 18.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.7 MB 20.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.7 MB 18.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.7/2.7 MB 12.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.7 MB 8.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.7 MB 8.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.7 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.6 MB/s eta 0:00:00
# Downloading imageio-2.34.0-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.4 kB ? eta -:--:--
#    ---------------------------------------  307.2/313.4 kB ? eta -:--:--
#    ---------------------------------------  307.2/313.4 kB ? eta -:--:--
#    ---------------------------------------  307.2/313.4 kB ? eta -:--:--
#    ---------------------------------------  307.2/313.4 kB ? eta -:--:--
#    ---------------------------------------  307.2/313.4 kB ? eta -:--:--
#    ---------------------------------------  307.2/313.4 kB ? eta -:--:--
#    ---------------------------------------- 313.4/313.4 kB 1.1 MB/s eta 0:00:00
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 25.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 22.7 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 22.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.6 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.9 MB/s eta 0:00:00
# Downloading langchain_community-0.0.20-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    --------------------- ------------------ 0.9/1.7 MB 19.0 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 17.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 9.7 MB/s eta 0:00:00
# Downloading langchain_core-0.1.23-py3-none-any.whl (241 kB)
#    ---------------------------------------- 0.0/241.2 kB ? eta -:--:--
#    ---------------------------------------  235.5/241.2 kB ? eta -:--:--
#    ---------------------------------------- 241.2/241.2 kB 2.9 MB/s eta 0:00:00
# Downloading langsmith-0.0.87-py3-none-any.whl (55 kB)
#    ---------------------------------------- 0.0/55.4 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.4 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.4 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.4 kB ? eta -:--:--
#    ---------------------------------------- 55.4/55.4 kB 322.2 kB/s eta 0:00:00
# Downloading mmh3-4.1.0-cp311-cp311-win_amd64.whl (31 kB)
# Downloading numba-0.57.1-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------- ------------------------- 0.9/2.6 MB 19.0 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 20.3 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 18.8 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 20.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 12.5 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp311-cp311-win_amd64.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#     --------------------------------------- 0.2/14.8 MB ? eta -:--:--
#    - -------------------------------------- 0.7/14.8 MB 9.1 MB/s eta 0:00:02
#    -- ------------------------------------- 1.0/14.8 MB 12.1 MB/s eta 0:00:02
#    -- ------------------------------------- 1.1/14.8 MB 6.2 MB/s eta 0:00:03
#    --- ------------------------------------ 1.2/14.8 MB 6.2 MB/s eta 0:00:03
#    ------ --------------------------------- 2.6/14.8 MB 9.6 MB/s eta 0:00:02
#    -------- ------------------------------- 3.3/14.8 MB 10.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.1/14.8 MB 11.3 MB/s eta 0:00:01
#    ------------- -------------------------- 4.9/14.8 MB 12.5 MB/s eta 0:00:01
#    --------------- ------------------------ 5.8/14.8 MB 13.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.4/14.8 MB 13.2 MB/s eta 0:00:01
#    -------------------- ------------------- 7.6/14.8 MB 13.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.5/14.8 MB 14.6 MB/s eta 0:00:01
#    ------------------------- -------------- 9.3/14.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------- ------------ 10.2/14.8 MB 14.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.0/14.8 MB 16.0 MB/s eta 0:00:01
#    ------------------------------- -------- 11.8/14.8 MB 19.3 MB/s eta 0:00:01
#    --------------------------------- ------ 12.3/14.8 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.9/14.8 MB 17.7 MB/s eta 0:00:01
#    ------------------------------------ --- 13.7/14.8 MB 18.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.8 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 17.2 MB/s eta 0:00:01
# ...
#    ---------------------------------------  45.6/46.2 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 9.6 MB/s eta 0:00:00
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#    ---------------------------------- ----- 61.4/71.5 kB ? eta -:--:--
#    ---------------------------------------- 71.5/71.5 kB 987.8 kB/s eta 0:00:00
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
#    ---------------------------------------- 0.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    ---------------------------------------- 224.5/224.5 kB 3.4 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------  337.9/345.4 kB 21.8 MB/s eta 0:00:01
#    --------------------------------------  337.9/345.4 kB 21.8 MB/s eta 0:00:01
#    --------------------------------------  337.9/345.4 kB 21.8 MB/s eta 0:00:01
#    --------------------------------------  337.9/345.4 kB 21.8 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 1.7 MB/s eta 0:00:00
# Downloading watchfiles-0.21.0-cp311-none-win_amd64.whl (280 kB)
#    ---------------------------------------- 0.0/280.1 kB ? eta -:--:--
#    ---------------------------------------  276.5/280.1 kB ? eta -:--:--
#    ---------------------------------------  276.5/280.1 kB ? eta -:--:--
#    ---------------------------------------  276.5/280.1 kB ? eta -:--:--
#    ---------------------------------------  276.5/280.1 kB ? eta -:--:--
#    ---------------------------------------- 280.1/280.1 kB 1.3 MB/s eta 0:00:00
# Downloading websocket_client-1.7.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.5 kB ? eta -:--:--
#    ----------------------------------- ---- 51.2/58.5 kB ? eta -:--:--
#    ----------------------------------- ---- 51.2/58.5 kB ? eta -:--:--
#    ----------------------------------- ---- 51.2/58.5 kB ? eta -:--:--
#    ----------------------------------- ---- 51.2/58.5 kB ? eta -:--:--
#    ---------------------------------------- 58.5/58.5 kB 237.5 kB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------  2.3/2.3 MB 73.7 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 73.7 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 73.7 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 73.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 12.2 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.7 kB ? eta -:--:--
#    ------------------------------------- -- 71.7/76.7 kB ? eta -:--:--
#    ---------------------------------------- 76.7/76.7 kB 841.5 kB/s eta 0:00:00
# Downloading databases-0.8.0-py3-none-any.whl (22 kB)
# Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#    ---------------------------------------- 0.0/253.7 kB ? eta -:--:--
#    -------------------------------------- - 245.8/253.7 kB ? eta -:--:--
#    -------------------------------------- - 245.8/253.7 kB ? eta -:--:--
#    ---------------------------------------- 253.7/253.7 kB 3.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.5 kB ? eta -:--:--
#    ---------------------------------------  143.4/143.5 kB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  143.4/143.5 kB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 143.5/143.5 kB 1.4 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl (29 kB)
# Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.5 kB ? eta -:--:--
#    -------------------------------------- - 174.1/181.5 kB ? eta -:--:--
#    ---------------------------------------- 181.5/181.5 kB 2.7 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.6 kB ? eta -:--:--
#    ---------------------------------------  184.3/187.6 kB ? eta -:--:--
#    ---------------------------------------- 187.6/187.6 kB 2.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.48.1-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------------------- -------- 1.7/2.2 MB 54.8 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 46.0 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 46.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 15.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 588.2 kB/s eta 0:00:00
# Downloading msgpack-1.0.7-cp311-cp311-win_amd64.whl (222 kB)
#    ---------------------------------------- 0.0/222.9 kB ? eta -:--:--
#    ------------------------------------- - 215.0/222.9 kB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 222.9/222.9 kB 2.3 MB/s eta 0:00:00
# Downloading pooch-1.8.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------  61.4/62.7 kB ? eta -:--:--
#    ---------------------------------------  61.4/62.7 kB ? eta -:--:--
#    ---------------------------------------  61.4/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 336.2 kB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------  102.4/103.1 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  102.4/103.1 kB 6.1 MB/s eta 0:00:01
#    -------------------------------------- 103.1/103.1 kB 852.3 kB/s eta 0:00:00
# Downloading soxr-0.3.7-cp311-cp311-win_amd64.whl (184 kB)
#    ---------------------------------------- 0.0/184.7 kB ? eta -:--:--
#    ---------------------------------------  184.3/184.7 kB ? eta -:--:--
#    ---------------------------------------- 184.7/184.7 kB 2.2 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp311-cp311-win_amd64.whl (37 kB)
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading pywavelets-1.5.0-cp311-cp311-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    --------------------- ------------------ 2.3/4.3 MB 48.6 MB/s eta 0:00:01
#    --------------------- ------------------ 2.3/4.3 MB 48.6 MB/s eta 0:00:01
#    --------------------- ------------------ 2.3/4.3 MB 48.6 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 10.1 MB/s eta 0:00:00
# Building wheels for collected packages: pygltflib, pypika, umap-learn
#   Building wheel for pygltflib (pyproject.toml): started
#   Building wheel for pygltflib (pyproject.toml): finished with status 'done'
#   Created wheel for pygltflib: filename=pygltflib-1.16.1-py3-none-any.whl size=27197 sha256=78c6ee3680bbcad473798682a658650e8852cdca18d543e5b41f51ba7a09eb45
#   Stored in directory: c:\users\ghadf\appdata\local\pip\cache\wheels\04\ff\8c\86754a2795e826568c0464a00ca03ca29a5468148bb0406d65
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53836 sha256=49c1da1866c36afc9a9427262bde4a7fd6b6607382482c666eb0d5d1dfbffd26
#   Stored in directory: c:\users\ghadf\appdata\local\pip\cache\wheels\a3\01\bd\4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
#   Building wheel for umap-learn (pyproject.toml): started
#   Building wheel for umap-learn (pyproject.toml): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86925 sha256=eda19cd0d3afd2e408381bf0062e9ec7cb8f778906dbf7043f87a112e89a26d6
#   Stored in directory: c:\users\ghadf\appdata\local\pip\cache\wheels\de\07\2e\814a6ee82e37528f2044a609a431028375b149bc31f03c0e27
# Successfully built pygltflib pypika umap-learn
# Installing collected packages: rfc3986, pytz, pyreadline3, pypika, mpmath, monotonic, mmh3, flatbuffers, filetype, appdirs, zipp, xxhash, wrapt, winregistry, win32-setctime, widgetsnbextension, websockets, websocket-client, validators, tzdata, toml, threadpoolctl, termcolor, tenacity, tabulate, sympy, sniffio, safetensors, regex, PyYAML, python-dotenv, pyproject_hooks, pyparsing, pycparser, pyasn1, pyarrow-hotfix, pulsar-client, protobuf, prettytable, pillow, overrides, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, oauthlib, numpy, networkx, mypy-extensions, multidict, msgpack, marshmallow, llvmlite, lazy_loader, kiwisolver, jupyterlab-widgets, jsonpointer, joblib, importlib-resources, humanfriendly, httptools, h11, grpcio, greenlet, fsspec, frozenlist, fonttools, filelock, distro, diskcache, dill, cycler, cachetools, bcrypt, backoff, av, audioread, attrs, asgiref, aiosqlite, aiofiles, yarl, uvicorn, typing-inspect, trimesh, tiktoken, tifffile, SQLAlchemy, soxr, scipy, rsa, requests-oauthlib, PyWavelets, pyasn1-modules, pyarrow, py-machineid, posthog, pooch, pandas, opentelemetry-proto, numba, multiprocess, loguru, jsonpatch, importlib-metadata, imageio, imagecodecs, huggingface-hub, h5py, googleapis-common-protos, deprecated, contourpy, coloredlogs, chroma-hnswlib, cffi, build, anyio, aiosignal, watchfiles, tokenizers, starlette, soundfile, scikit-learn, scikit-image, pydantic-settings, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, matplotlib, langsmith, imagehash, httpcore, google-auth, dataclasses-json, databases, aiohttp, transformers, pynndescent, pygltflib, opentelemetry-sdk, opentelemetry-instrumentation, librosa, langchain-core, kubernetes, ipywidgets, httpx, fastapi, cleanvision, cleanlab, umap-learn, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, openai, langchain-community, datasets, opentelemetry-instrumentation-fastapi, langchain-openai, langchain, renumics-spotlight, chromadb
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.3
#     Uninstalling numpy-1.26.3:
#       Successfully uninstalled numpy-1.26.3
# Successfully installed PyWavelets-1.5.0 PyYAML-6.0.1 SQLAlchemy-1.4.51 aiofiles-23.2.1 aiohttp-3.9.3 aiosignal-1.3.1 aiosqlite-0.19.0 anyio-4.2.0 appdirs-1.4.4 asgiref-3.7.2 attrs-23.2.0 audioread-3.0.1 av-11.0.0 backoff-2.2.1 bcrypt-4.1.2 build-1.0.3 cachetools-5.3.2 cffi-1.16.0 chroma-hnswlib-0.7.3 chromadb-0.4.22 cleanlab-2.5.0 cleanvision-0.3.6 coloredlogs-15.0.1 contourpy-1.2.0 cycler-0.12.1 databases-0.8.0 dataclasses-json-0.6.4 datasets-2.17.0 deprecated-1.2.14 dill-0.3.8 diskcache-5.6.3 distro-1.9.0 fastapi-0.109.2 filelock-3.13.1 filetype-1.2.0 flatbuffers-23.5.26 fonttools-4.48.1 frozenlist-1.4.1 fsspec-2023.10.0 google-auth-2.27.0 googleapis-common-protos-1.62.0 greenlet-3.0.3 grpcio-1.60.1 h11-0.14.0 h5py-3.10.0 httpcore-0.16.3 httptools-0.6.1 httpx-0.23.3 huggingface-hub-0.20.3 humanfriendly-10.0 imagecodecs-2024.1.1 imagehash-4.3.1 imageio-2.34.0 importlib-metadata-6.11.0 importlib-resources-5.7.1 ipywidgets-8.1.2 joblib-1.3.2 jsonpatch-1.33 jsonpointer-2.4 jupyterlab-widgets-3.0.10 kiwisolver-1.4.5 kubernetes-29.0.0 langchain-0.1.7 langchain-community-0.0.20 langchain-core-0.1.23 langchain-openai-0.0.6 langsmith-0.0.87 lazy_loader-0.3 librosa-0.10.1 llvmlite-0.40.1 loguru-0.7.2 marshmallow-3.20.2 matplotlib-3.8.2 mmh3-4.1.0 monotonic-1.6 mpmath-1.3.0 msgpack-1.0.7 multidict-6.0.5 multiprocess-0.70.16 mypy-extensions-1.0.0 networkx-3.2.1 numba-0.57.1 numpy-1.24.4 oauthlib-3.2.2 onnxruntime-1.17.0 openai-1.12.0 opentelemetry-api-1.22.0 opentelemetry-exporter-otlp-proto-common-1.22.0 opentelemetry-exporter-otlp-proto-grpc-1.22.0 opentelemetry-instrumentation-0.43b0 opentelemetry-instrumentation-asgi-0.43b0 opentelemetry-instrumentation-fastapi-0.43b0 opentelemetry-proto-1.22.0 opentelemetry-sdk-1.22.0 opentelemetry-semantic-conventions-0.43b0 opentelemetry-util-http-0.43b0 orjson-3.9.13 overrides-7.7.0 pandas-2.2.0 pillow-10.2.0 pooch-1.8.0 posthog-3.4.1 prettytable-3.9.0 protobuf-4.25.2 pulsar-client-3.4.0 py-machineid-0.5.1 pyarrow-14.0.2 pyarrow-hotfix-0.6 pyasn1-0.5.1 pyasn1-modules-0.3.0 pycparser-2.21 pydantic-settings-2.1.0 pygltflib-1.16.1 pynndescent-0.5.11 pyparsing-3.1.1 pypika-0.48.9 pyproject_hooks-1.0.0 pyreadline3-3.4.1 python-dotenv-1.0.1 pytz-2024.1 regex-2023.12.25 renumics-spotlight-1.6.4 requests-oauthlib-1.3.1 rfc3986-1.5.0 rsa-4.9 safetensors-0.4.2 scikit-image-0.22.0 scikit-learn-1.4.0 scipy-1.12.0 sniffio-1.3.0 soundfile-0.12.1 soxr-0.3.7 starlette-0.36.3 sympy-1.12 tabulate-0.9.0 tenacity-8.2.3 termcolor-2.4.0 threadpoolctl-3.2.0 tifffile-2024.2.12 tiktoken-0.6.0 tokenizers-0.15.2 toml-0.10.2 transformers-4.37.2 trimesh-4.1.3 typing-inspect-0.9.0 tzdata-2024.1 umap-learn-0.5.5 uvicorn-0.27.1 validators-0.22.0 watchfiles-0.21.0 websocket-client-1.7.0 websockets-12.0 widgetsnbextension-4.0.10 win32-setctime-1.1.0 winregistry-1.1.1 wrapt-1.16.0 xxhash-3.4.1 yarl-1.9.4 zipp-3.17.0

# %%
# %env OPENAI_API_KEY=<>
# Out:
# env: OPENAI_API_KEY=<>

# %% [markdown]
# Split and Create embeddings for the dataset
#
# You can skip this section and download a database with embeddings of the Formula One Dataset.
#
# To create the embeddings on your own you first need to set up the embeddings model and the vectorstore. Here we use text-embedding-ada-002 from OpenAIEmbeddings and a vectorstore using ChromaDB:

# %%
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.chroma import Chroma

embeddings_model = OpenAIEmbeddings(model="text-embedding-ada-002")
docs_vectorstore = Chroma(
    collection_name="docs_store",
    embedding_function=embeddings_model,
    persist_directory="docs-db",
)

# %% [markdown]
# To fill the vector store we load the html documents using the BSHTMLLoader:

# %%
from langchain_community.document_loaders import BSHTMLLoader, DirectoryLoader
import getpass
username = getpass.getuser()


loader = DirectoryLoader(
    "docs",
    glob="*.html",
    loader_cls=BSHTMLLoader,
    loader_kwargs={"open_encoding": "utf-8"},
    recursive=True,
    show_progress=True,
)
docs = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain_community.document_loaders import BSHTMLLoader, DirectoryLoader
#       2 import getpass
#       3 username = getpass.getuser()
#
# File c:\Users\ghadf\vscode_projects\.venv\Lib\site-packages\langchain_community\document_loaders\__init__.py:163
#     149 from langchain_community.document_loaders.org_mode import UnstructuredOrgModeLoader
#     150 from langchain_community.document_loaders.pdf import (
#     151     AmazonTextractPDFLoader,
#     152     MathpixPDFLoader,
#    (...)
#     161     UnstructuredPDFLoader,
#     162 )
# --> 163 from langchain_community.document_loaders.pebblo import PebbloSafeLoader
#     164 from langchain_community.document_loaders.polars_dataframe import PolarsDataFrameLoader
#     165 from langchain_community.document_loaders.powerpoint import UnstructuredPowerPointLoader
#
# File c:\Users\ghadf\vscode_projects\.venv\Lib\site-packages\langchain_community\document_loaders\pebblo.py:5
#       3 import logging
#       4 import os
# ----> 5 import pwd
#       6 import uuid
#       7 from http import HTTPStatus
#
# ModuleNotFoundError: No module named 'pwd'

# %% [markdown]
# Divide them into smaller chunks

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200, add_start_index=True
)
splits = text_splitter.split_documents(docs)

# %% [markdown]
# Additionally you can create an id that can be reconstructed from the metadata. This allows to find the embeddings in the db if you only have the document with its content and metadata. You can add all to the database and store it:

# %%
import hashlib
import json
from langchain_core.documents import Document

def stable_hash(doc: Document) -> str:
    """
    Stable hash document based on its metadata.
    """
    return hashlib.sha1(json.dumps(doc.metadata, sort_keys=True).encode()).hexdigest()

split_ids = list(map(stable_hash, splits))
docs_vectorstore.add_documents(splits, ids=split_ids)
docs_vectorstore.persist()

# %% [markdown]
# Build the LangChain
#
# First, you need to choose an LLM Model. Here, we use GPT-4. Also, you need to prepare the retriever to use the vector store:

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4", temperature=0.0)
retriever = docs_vectorstore.as_retriever(search_kwargs={"k": 20})

# %% [markdown]
# Setting the temperature parameter to 0.0 when initializing the ChatOpenAI model ensures deterministic output.
#
# Now, let’s create a prompt for RAG. The LLM will be provided with the user’s question and the retrieved documents as a context to answer the question. It is also instructed to provide the sources that allowed its answer:

# %%
from langchain_core.prompts import ChatPromptTemplate

template = """
You are an assistant for question-answering tasks.
Given the following extracted parts of a long document and a question, create a final answer with references ("SOURCES").
If you don't know the answer, just say that you don't know. Don't try to make up an answer.
ALWAYS return a "SOURCES" part in your answer.

QUESTION: {question}
=========
{source_documents}
=========
FINAL ANSWER: """
prompt = ChatPromptTemplate.from_template(template)

# %% [markdown]
# Next, set up a processing pipeline that starts by formatting the retrieved documents to contain the page content and the source file path. This formatted input is then fed into a language model (LLM) step that generates an answer based on the combined user question and document context.

# %%
from typing import List

from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser


def format_docs(docs: List[Document]) -> str:
    return "\n\n".join(
        f"Content: {doc.page_content}\nSource: {doc.metadata['source']}" for doc in docs
    )


rag_chain_from_docs = (
    RunnablePassthrough.assign(
        source_documents=(lambda x: format_docs(x["source_documents"]))
    )
    | prompt
    | llm
    | StrOutputParser()
)
rag_chain = RunnableParallel(
    {
        "source_documents": retriever,
        "question": RunnablePassthrough(),
    }
).assign(answer=rag_chain_from_docs)

# %% [markdown]
# Ask a Question
#
# The RAG application is now ready to answer questions:

# %%
question = "Who built the nuerburgring"
response = rag_chain.invoke(question)
response["answer"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 question = "Who built the nuerburgring"
# ----> 2 response = rag_chain.invoke(question)
#       3 response["answer"]
#
# NameError: name 'rag_chain' is not defined

# %% [markdown]
# Visualize
#
# To explore the data in Spotlight, we use Pandas DataFrame to organize our data. Let’s start with the extraction of the text snippets and their embeddings from the vector store. In addition, let’s mark the correct answer:

# %%
import pandas as pd

response = docs_vectorstore.get(include=["metadatas", "documents", "embeddings"])
df = pd.DataFrame(
    {
        "id": response["ids"],
        "source": [metadata.get("source") for metadata in response["metadatas"]],
        "page": [metadata.get("page", -1) for metadata in response["metadatas"]],
        "document": response["documents"],
        "embedding": response["embeddings"],
    }
)
df["contains_answer"] = df["document"].apply(lambda x: "Eichler" in x)
df["contains_answer"].to_numpy().nonzero()

# %% [markdown]
# The question and the associated answer are also projected into the Embeddings Space. They are processed in the same way as the text snippets:

# %%
question_row = pd.DataFrame(
    {
        "id": "question",
        "question": question,
        "embedding": embeddings_model.embed_query(question),
    }
)
answer_row = pd.DataFrame(
    {
        "id": "answer",
        "answer": answer,
        "embedding": embeddings_model.embed_query(answer),
    }
)
df = pd.concat([question_row, answer_row, df])

# %%
import numpy as np
question_embedding = embeddings_model.embed_query(question)
df["dist"] = df.apply(
    lambda row: np.linalg.norm(
        np.array(row["embedding"]) - question_embedding
    ),
    axis=1,
)

# %% [markdown]
# This can additionally be used for visualization and will be stored in the column distance:

# %%
from renumics import spotlight
spotlight.show(df)

# %% [markdown]
# It will open a new browser window. The top-left table section displays all fields of the dataset. You can use the “visible column” button to select the columns “question”, “answer”, “source”, “document”, and “dist”. Ordering the table by “dist” shows the question, answer, and the most relevant document snippets on top. Select the first 14 rows to highlight them in the similarity map on the top right.

# %% [markdown]
# What’s next?
#
# The good visualization of a single question, answer, and the related documents shows a large potential for RAG. Using dimensionality reduction techniques can make the embedding space accessible for users and developers. The utility of the specific presentation in this article is still very limited. It remains exciting to explore the possibilities of these methods in presenting many questions and thus illustrating the use of a RAG system in operation or checking the coverage of the embedding space through evaluation questions. Stay tuned for more articles to follow.
